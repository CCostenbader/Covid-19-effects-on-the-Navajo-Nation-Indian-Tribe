# %% [markdown]
# # Final Project

# %% [markdown]
# ## IMPORTING LIBRARIES

# %%
import pandas as pd

# %% [markdown]
# ## IMPORTING DATA SET

# %%
covid = pd.read_csv("CovidDataSet.csv")

# %%
covid.head()
# Out:
#    FIPS Admin2 Province_State Country_Region          Last_Update       Lat  \
# 0   NaN    NaN            NaN    Afghanistan  2021-02-08 05:22:39  33.93911
# 1   NaN    NaN            NaN        Albania  2021-02-08 05:22:39  41.15330
# 2   NaN    NaN            NaN        Algeria  2021-02-08 05:22:39  28.03390
# 3   NaN    NaN            NaN        Andorra  2021-02-08 05:22:39  42.50630
# 4   NaN    NaN            NaN         Angola  2021-02-08 05:22:39 -11.20270
#
#        Long_  Confirmed  Deaths  Recovered   Active Combined_Key  \
# 0  67.709953      55335    2410      48041   4884.0  Afghanistan
# 1  20.168300      85336    1460      51444  32432.0      Albania
# 2   1.659600     109088    2914      74692  31482.0      Algeria
# 3   1.521800      10251     106       9533    612.0      Andorra
# 4  17.873900      20086     475      18540   1071.0       Angola
#
#    Incident_Rate  Case_Fatality_Ratio
# 0     142.145796             4.355291
# 1    2965.320731             1.710884
# ...

# %% [markdown]
# ### RE-CODING "FIPS" COLUMN TO REFLECT ONLY ADDRESSES IN ARIZONA AND NEW MEXICO
# #### STILL NEED TO CONFIRM IF THE LIST WE HAVE INCLUDES ALL THE COUNTIES IN THE STATES BEING PULLED FROM

# %%
covid2 = covid[covid["FIPS"].isin([4001, 4003, 4005, 4007, 4009, 4011, 4012, 4013, 4015, 4017, 4019, 4021, 4023, 4025,4027,35001, 35003, 35005, 35006, 35007, 35009, 35011, 35013, 35015, 35017, 35019, 35021, 35023, 35025, 35027, 35028, 35029, 35031, 35033, 35035, 35037, 35039, 35041, 35045, 35047, 35043, 35049, 35051, 35053, 35055, 35057, 35059, 35061])]

# %%
covid2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48 entries, 749 to 2522
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   FIPS                 48 non-null     float64
#  1   Admin2               48 non-null     object
#  2   Province_State       48 non-null     object
#  3   Country_Region       48 non-null     object
#  4   Last_Update          48 non-null     object
#  5   Lat                  48 non-null     float64
#  6   Long_                48 non-null     float64
#  7   Confirmed            48 non-null     int64
#  8   Deaths               48 non-null     int64
#  9   Recovered            48 non-null     int64
#  10  Active               48 non-null     float64
#  11  Combined_Key         48 non-null     object
#  12  Incident_Rate        48 non-null     float64
#  13  Case_Fatality_Ratio  48 non-null     float64
#  14  Navajo               0 non-null      object
# ...

# %%
covid2.head()
# Out:
#        FIPS    Admin2 Province_State Country_Region          Last_Update  \
# 749  4001.0    Apache        Arizona             US  2021-02-08 05:22:39
# 750  4003.0   Cochise        Arizona             US  2021-02-08 05:22:39
# 751  4005.0  Coconino        Arizona             US  2021-02-08 05:22:39
# 752  4007.0      Gila        Arizona             US  2021-02-08 05:22:39
# 753  4009.0    Graham        Arizona             US  2021-02-08 05:22:39
#
#            Lat       Long_  Confirmed  Deaths  Recovered   Active  \
# 749  35.394650 -109.489238       9854     326          0   9528.0
# 750  31.879347 -109.751609      10602     238          0  10364.0
# 751  35.838834 -111.770718      15675     288          0  15387.0
# 752  33.801901 -110.813278       6159     199          0   5960.0
# 753  32.931669 -109.888218       5158      69          0   5089.0
#
#               Combined_Key  Incident_Rate  Case_Fatality_Ratio
# 749    Apache, Arizona, US   13707.624466             3.308301
# ...

# %%
covid2.tail()
# Out:
#          FIPS    Admin2 Province_State Country_Region          Last_Update  \
# 2517  35053.0   Socorro     New Mexico             US  2021-02-08 05:22:39
# 2518  35055.0      Taos     New Mexico             US  2021-02-08 05:22:39
# 2519  35057.0  Torrance     New Mexico             US  2021-02-08 05:22:39
# 2521  35059.0     Union     New Mexico             US  2021-02-08 05:22:39
# 2522  35061.0  Valencia     New Mexico             US  2021-02-08 05:22:39
#
#             Lat       Long_  Confirmed  Deaths  Recovered  Active  \
# 2517  34.007155 -106.929835       1165      47          0  1118.0
# 2518  36.580060 -105.631020       1468      46          0  1422.0
# 2519  34.640484 -105.850895        610      12          0   598.0
# 2521  36.481264 -103.470962        212       8          0   204.0
# 2522  34.716698 -106.810373       5919      86          0  5833.0
#
#                   Combined_Key  Incident_Rate  Case_Fatality_Ratio
# ...

# %%
 def FIPS (series): 
    if series == 4003:
        return 0
    if series == 4001: 
        return 1
    if series == 40012:
        return 0
    if series == 4005: 
        return 1
    if series == 40012:
        return 0
    if series == 4005: 
        return 1
    if series == 4007:
        return 0
    if series == 4017: 
        return 1
    if series == 35006:
        return 0
    if series == 35031: 
        return 1
    if series == 35001:
        return 0
    if series == 35045: 
        return 1
    if series == 35001:
        return 0
    if series == 35045: 
        return 1
    if series == 4012:
        return 0
    if series == 4013: 
        return 0
    if series == 4015:
        return 0
    if series == 4019: 
        return 0
    if series == 4021:
        return 0
    if series == 4023: 
        return 0
    if series == 4025:
        return 0
    if series == 4027: 
        return 0
    if series == 35029:
        return 0
    if series == 35003: 
        return 0
    if series == 35028:
        return 0
    if series == 35033: 
        return 0
    if series == 35035:
        return 0
    if series == 35013: 
        return 0
    if series == 35011:
        return 0
    if series == 35009: 
        return 0
    if series == 35039:
        return 0
    if series == 35007: 
        return 0
    if series == 35028:
        return 0
    if series == 35017: 
        return 0
    if series == 35027:
        return 0
    if series == 35025: 
        return 0
    if series == 35015:
        return 0
    if series == 35019: 
        return 0
    if series == 35021:
        return 0
    if series == 35037: 
        return 0
    if series == 35047:
        return 0
    if series == 35043: 
        return 0
    if series == 35049:
        return 0
    if series == 35051: 
        return 0
    if series == 35053:
        return 0
    if series == 35055: 
        return 0
    if series == 35057:
        return 0
    if series == 90035: 
        return 0
    if series == 35059:
        return 0
    if series == 35061: 
        return 0

# %%
covid2['Navajo'] = covid2['FIPS'].apply(FIPS)
# Out:
# <ipython-input-83-f755f739a500>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid2['Navajo'] = covid2['FIPS'].apply(FIPS)

# %%
covid2.head()
# Out:
#        FIPS    Admin2 Province_State Country_Region          Last_Update  \
# 749  4001.0    Apache        Arizona             US  2021-02-08 05:22:39
# 750  4003.0   Cochise        Arizona             US  2021-02-08 05:22:39
# 751  4005.0  Coconino        Arizona             US  2021-02-08 05:22:39
# 752  4007.0      Gila        Arizona             US  2021-02-08 05:22:39
# 753  4009.0    Graham        Arizona             US  2021-02-08 05:22:39
#
#            Lat       Long_  Confirmed  Deaths  Recovered   Active  \
# 749  35.394650 -109.489238       9854     326          0   9528.0
# 750  31.879347 -109.751609      10602     238          0  10364.0
# 751  35.838834 -111.770718      15675     288          0  15387.0
# 752  33.801901 -110.813278       6159     199          0   5960.0
# 753  32.931669 -109.888218       5158      69          0   5089.0
#
#               Combined_Key  Incident_Rate  Case_Fatality_Ratio  Navajo
# ...

# %%
pd.options.display.max_columns = 1000

# %%
covid2.head()
# Out:
#        FIPS    Admin2 Province_State Country_Region          Last_Update  \
# 749  4001.0    Apache        Arizona             US  2021-02-08 05:22:39
# 750  4003.0   Cochise        Arizona             US  2021-02-08 05:22:39
# 751  4005.0  Coconino        Arizona             US  2021-02-08 05:22:39
# 752  4007.0      Gila        Arizona             US  2021-02-08 05:22:39
# 753  4009.0    Graham        Arizona             US  2021-02-08 05:22:39
#
#            Lat       Long_  Confirmed  Deaths  Recovered   Active  \
# 749  35.394650 -109.489238       9854     326          0   9528.0
# 750  31.879347 -109.751609      10602     238          0  10364.0
# 751  35.838834 -111.770718      15675     288          0  15387.0
# 752  33.801901 -110.813278       6159     199          0   5960.0
# 753  32.931669 -109.888218       5158      69          0   5089.0
#
#               Combined_Key  Incident_Rate  Case_Fatality_Ratio  Navajo
# ...

# %%
covid2.Navajo.value_counts()
# Out:
# 0.0    38
# 1.0     5
# Name: Navajo, dtype: int64
